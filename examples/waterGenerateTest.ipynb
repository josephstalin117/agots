# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 5000
N = 1
K = 1

plt.figure(figsize=(18,8))
dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=10, initial_value_max=20)


for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#      x0
# x0  1.0

# %%
dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=10, initial_value_max=20)
df
for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

# %%
df = dg.add_outliers({'extreme': [{'n': 0, 'timestamps': [(50,), (190,)]}],
                      'shift':   [{'n': 0, 'timestamps': [(1000,1900)]}],
                      'trend':   [{'n': 0, 'timestamps': [(2200, 2400)]}],
                      'variance':[{'n': 0, 'timestamps': [(5000, 6000)]}]})


plt.figure(figsize=(18,8))
for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()
df
# Out:
#               x0
# 0       3.000000
# 1       1.572558
# 2       1.873181
# 3       1.361140
# 4       1.408475
# ...          ...
# 9995 -153.747826
# 9996 -152.957422
# 9997 -153.845870
# 9998 -153.656768
# 9999 -155.036609
#
# [10000 rows x 1 columns]
